# %% [markdown]
# <h2 style='color:green' align='center'>Indian Entrepreneurs Image Classification<h2>

# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# <h3 style='color:blue'> Preprocessing: Detecting the face and eyes</h3>

# %% [markdown]
# #### Now how do you detect face and eyes?

# %%
img = cv2.imread('./test_images/ratan tata.jpg')
img.shape
# Out:
# (1000, 1000, 3)

# %%
plt.imshow(img)  #here (1000,1000,3) == (height,width,rgb value of the image)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (1000, 1000)

# %%
gray
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [ 39,  43,  45, ...,  56,  58,  59],
#        [ 45,  49,  52, ...,  58,  62,  64],
#        [ 55,  59,  63, ...,  66,  71,  74]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[272, 278, 414, 414]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (272, 278, 414, 414)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %% [markdown]
# <h3 style='color:purple'>(2) Preprocessing: Crop the facial region of the image</h3>

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (414, 414, 3)

# %% [markdown]
# <h3 style='color:purple'>(3) Preprocessing: Use wavelet transform as a feature for traning our model</h3>

# %% [markdown]
# #### In wavelet transformed image, you can see edges clearly and that can give us clues on various facial features such as eyes, nose, lips etc

# %% [markdown]
# ### Wavelet transform

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %% [markdown]
# #### You can see above a wavelet transformed image that gives clues on facial features such as eyes, nose, lips etc. This along with raw pixel image can be used as an input for our classifier

# %% [markdown]
# <h3 style='color:purple'>(3) Preprocessing: Load image, detect face. If eyes >=2, then save and crop the face region</h3>

# %% [markdown]
# ####  Lets write a python function that can take input image and returns cropped image (if face and eyes >=2 are detected)

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    #print(img)

    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_images/ratan tata.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/ratan tata.jpg')
plt.imshow(cropped_image)

# %% [markdown]
# **In below image face is not very clear and it doesn't have two eyes clearly visible**

# %%
org_image_obstructed = cv2.imread('./test_images/ratan tata 2.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_images/ratan tata 2.jpg')
cropped_image_no_2_eyes

# %% [markdown]
# **Above cropped_image_no_2_eyes is None which means we should ignore this image and we will not use such image for model training**

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/azim-premji',
#  './dataset/lakshmi_niwas_mittal',
#  './dataset/mukesh_ambani',
#  './dataset/nr_narayana_murthy',
#  './dataset/ratan_tata',
#  './dataset/ritesh_agarwal',
#  './dataset/satya_nadella',
#  './dataset/shantanu_narayen',
#  './dataset/sundar_pichai']

# %% [markdown]
# **Go through all images in dataset folder and create cropped images for them. There will be cropped folder inside dataset folder after you run this code**

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        #print(entry)
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/azim-premji
# Generating cropped images in folder:  ./dataset/cropped/lakshmi_niwas_mittal
# Generating cropped images in folder:  ./dataset/cropped/mukesh_ambani
# Generating cropped images in folder:  ./dataset/cropped/nr_narayana_murthy
# Generating cropped images in folder:  ./dataset/cropped/ratan_tata
# Generating cropped images in folder:  ./dataset/cropped/ritesh_agarwal
# Generating cropped images in folder:  ./dataset/cropped/satya_nadella
# Generating cropped images in folder:  ./dataset/cropped/shantanu_narayen
# Generating cropped images in folder:  ./dataset/cropped/sundar_pichai

# %% [markdown]
# ### Now you should have cropped folder under datasets folder that contains cropped images

# %% [markdown]
# ### Manually examine cropped folder and delete any unwanted images

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'azim-premji': ['./dataset/cropped/azim-premji\\zim-premji1.png',
#   './dataset/cropped/azim-premji\\zim-premji10.png',
#   './dataset/cropped/azim-premji\\zim-premji11.png',
#   './dataset/cropped/azim-premji\\zim-premji12.png',
#   './dataset/cropped/azim-premji\\zim-premji13.png',
#   './dataset/cropped/azim-premji\\zim-premji14.png',
#   './dataset/cropped/azim-premji\\zim-premji15.png',
#   './dataset/cropped/azim-premji\\zim-premji16.png',
#   './dataset/cropped/azim-premji\\zim-premji18.png',
#   './dataset/cropped/azim-premji\\zim-premji19.png',
#   './dataset/cropped/azim-premji\\zim-premji2.png',
#   './dataset/cropped/azim-premji\\zim-premji21.png',
#   './dataset/cropped/azim-premji\\zim-premji23.png',
#   './dataset/cropped/azim-premji\\zim-premji24.png',
#   './dataset/cropped/azim-premji\\zim-premji25.png',
#   './dataset/cropped/azim-premji\\zim-premji26.png',
#   './dataset/cropped/azim-premji\\zim-premji27.png',
#   './dataset/cropped/azim-premji\\zim-premji28.png',
#   './dataset/cropped/azim-premji\\zim-premji29.png',
#   './dataset/cropped/azim-premji\\zim-premji3.png',
#   './dataset/cropped/azim-premji\\zim-premji30.png',
#   './dataset/cropped/azim-premji\\zim-premji34.png',
#   './dataset/cropped/azim-premji\\zim-premji35.png',
#   './dataset/cropped/azim-premji\\zim-premji36.png',
#   './dataset/cropped/azim-premji\\zim-premji4.png',
#   './dataset/cropped/azim-premji\\zim-premji6.png',
#   './dataset/cropped/azim-premji\\zim-premji7.png',
#   './dataset/cropped/azim-premji\\zim-premji8.png',
#   './dataset/cropped/azim-premji\\zim-premji9.png'],
#  'lakshmi_niwas_mittal': ['./dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal1.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal10.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal11.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal12.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal13.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal14.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal17.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal18.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal19.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal2.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal21.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal22.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal23.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal24.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal25.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal26.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal27.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal28.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal29.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal30.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal31.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal32.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal34.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal35.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal36.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal37.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal38.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal4.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal41.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal42.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal43.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal44.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal45.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal47.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal48.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal49.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal5.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal50.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal52.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal53.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal6.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal7.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal8.png',
#   './dataset/cropped/lakshmi_niwas_mittal\\lakshmi_niwas_mittal9.png'],
#  'mukesh_ambani': ['./dataset/cropped/mukesh_ambani\\mukesh_ambani1.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani11.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani12.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani15.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani16.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani17.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani18.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani2.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani20.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani21.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani23.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani25.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani28.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani31.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani33.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani34.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani36.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani37.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani39.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani40.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani41.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani42.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani43.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani44.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani45.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani47.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani49.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani5.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani51.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani52.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani53.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani56.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani57.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani58.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani59.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani6.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani60.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani62.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani66.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani67.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani68.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani7.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani71.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani72.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani74.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani75.png',
#   './dataset/cropped/mukesh_ambani\\mukesh_ambani76.png'],
#  'nr_narayana_murthy': ['./dataset/cropped/nr_narayana_murthy\\nr_narayana_murthy13.png',
#   './dataset/cropped/nr_narayana_murthy\\nr_narayana_murthy14.png',
#   './dataset/cropped/nr_narayana_murthy\\nr_narayana_murthy16.png',
#   './dataset/cropped/nr_narayana_murthy\\nr_narayana_murthy17.png',
#   './dataset/cropped/nr_narayana_murthy\\nr_narayana_murthy18.png',
#   './dataset/cropped/nr_narayana_murthy\\nr_narayana_murthy19.png',
#   './dataset/cropped/nr_narayana_murthy\\nr_narayana_murthy2.png',
#   './dataset/cropped/nr_narayana_murthy\\nr_narayana_murthy20.png',
#   './dataset/cropped/nr_narayana_murthy\\nr_narayana_murthy21.png',
#   './dataset/cropped/nr_narayana_murthy\\nr_narayana_murthy22.png',
#   './dataset/cropped/nr_narayana_murthy\\nr_narayana_murthy23.png',
#   './dataset/cropped/nr_narayana_murthy\\nr_narayana_murthy25.png',
#   './dataset/cropped/nr_narayana_murthy\\nr_narayana_murthy26.png',
#   './dataset/cropped/nr_narayana_murthy\\nr_narayana_murthy32.png',
#   './dataset/cropped/nr_narayana_murthy\\nr_narayana_murthy5.png',
#   './dataset/cropped/nr_narayana_murthy\\nr_narayana_murthy6.png',
#   './dataset/cropped/nr_narayana_murthy\\nr_narayana_murthy8.png',
#   './dataset/cropped/nr_narayana_murthy\\nr_narayana_murthy9.png'],
#  'ratan_tata': ['./dataset/cropped/ratan_tata\\ratan_tata1.png',
#   './dataset/cropped/ratan_tata\\ratan_tata10.png',
#   './dataset/cropped/ratan_tata\\ratan_tata11.png',
#   './dataset/cropped/ratan_tata\\ratan_tata12.png',
#   './dataset/cropped/ratan_tata\\ratan_tata13.png',
#   './dataset/cropped/ratan_tata\\ratan_tata14.png',
#   './dataset/cropped/ratan_tata\\ratan_tata15.png',
#   './dataset/cropped/ratan_tata\\ratan_tata16.png',
#   './dataset/cropped/ratan_tata\\ratan_tata17.png',
#   './dataset/cropped/ratan_tata\\ratan_tata2.png',
#   './dataset/cropped/ratan_tata\\ratan_tata22.png',
#   './dataset/cropped/ratan_tata\\ratan_tata23.png',
#   './dataset/cropped/ratan_tata\\ratan_tata24.png',
#   './dataset/cropped/ratan_tata\\ratan_tata26.png',
#   './dataset/cropped/ratan_tata\\ratan_tata27.png',
#   './dataset/cropped/ratan_tata\\ratan_tata28.png',
#   './dataset/cropped/ratan_tata\\ratan_tata30.png',
#   './dataset/cropped/ratan_tata\\ratan_tata31.png',
#   './dataset/cropped/ratan_tata\\ratan_tata32.png',
#   './dataset/cropped/ratan_tata\\ratan_tata33.png',
#   './dataset/cropped/ratan_tata\\ratan_tata34.png',
#   './dataset/cropped/ratan_tata\\ratan_tata35.png',
#   './dataset/cropped/ratan_tata\\ratan_tata36.png',
#   './dataset/cropped/ratan_tata\\ratan_tata38.png',
#   './dataset/cropped/ratan_tata\\ratan_tata39.png',
#   './dataset/cropped/ratan_tata\\ratan_tata4.png',
#   './dataset/cropped/ratan_tata\\ratan_tata40.png',
#   './dataset/cropped/ratan_tata\\ratan_tata42.png',
#   './dataset/cropped/ratan_tata\\ratan_tata43.png',
#   './dataset/cropped/ratan_tata\\ratan_tata44.png',
#   './dataset/cropped/ratan_tata\\ratan_tata45.png',
#   './dataset/cropped/ratan_tata\\ratan_tata46.png',
#   './dataset/cropped/ratan_tata\\ratan_tata47.png',
#   './dataset/cropped/ratan_tata\\ratan_tata49.png',
#   './dataset/cropped/ratan_tata\\ratan_tata50.png',
#   './dataset/cropped/ratan_tata\\ratan_tata52.png',
#   './dataset/cropped/ratan_tata\\ratan_tata53.png',
#   './dataset/cropped/ratan_tata\\ratan_tata55.png',
#   './dataset/cropped/ratan_tata\\ratan_tata56.png',
#   './dataset/cropped/ratan_tata\\ratan_tata57.png',
#   './dataset/cropped/ratan_tata\\ratan_tata6.png',
#   './dataset/cropped/ratan_tata\\ratan_tata7.png',
#   './dataset/cropped/ratan_tata\\ratan_tata8.png',
#   './dataset/cropped/ratan_tata\\ratan_tata9.png'],
#  'ritesh_agarwal': ['./dataset/cropped/ritesh_agarwal\\ritesh_agarwal1.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal11.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal12.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal13.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal14.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal15.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal16.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal18.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal19.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal2.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal20.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal21.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal22.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal23.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal24.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal25.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal27.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal28.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal29.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal3.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal31.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal32.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal33.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal34.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal35.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal36.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal37.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal39.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal4.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal40.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal41.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal42.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal43.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal44.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal45.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal46.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal47.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal48.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal49.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal5.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal50.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal51.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal52.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal53.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal54.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal55.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal56.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal57.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal58.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal59.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal6.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal60.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal61.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal62.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal63.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal64.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal65.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal66.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal67.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal68.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal69.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal70.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal8.png',
#   './dataset/cropped/ritesh_agarwal\\ritesh_agarwal9.png'],
#  'satya_nadella': ['./dataset/cropped/satya_nadella\\satya_nadella1.png',
#   './dataset/cropped/satya_nadella\\satya_nadella10.png',
#   './dataset/cropped/satya_nadella\\satya_nadella12.png',
#   './dataset/cropped/satya_nadella\\satya_nadella13.png',
#   './dataset/cropped/satya_nadella\\satya_nadella14.png',
#   './dataset/cropped/satya_nadella\\satya_nadella16.png',
#   './dataset/cropped/satya_nadella\\satya_nadella17.png',
#   './dataset/cropped/satya_nadella\\satya_nadella18.png',
#   './dataset/cropped/satya_nadella\\satya_nadella19.png',
#   './dataset/cropped/satya_nadella\\satya_nadella2.png',
#   './dataset/cropped/satya_nadella\\satya_nadella20.png',
#   './dataset/cropped/satya_nadella\\satya_nadella21.png',
#   './dataset/cropped/satya_nadella\\satya_nadella22.png',
#   './dataset/cropped/satya_nadella\\satya_nadella23.png',
#   './dataset/cropped/satya_nadella\\satya_nadella25.png',
#   './dataset/cropped/satya_nadella\\satya_nadella26.png',
#   './dataset/cropped/satya_nadella\\satya_nadella28.png',
#   './dataset/cropped/satya_nadella\\satya_nadella29.png',
#   './dataset/cropped/satya_nadella\\satya_nadella3.png',
#   './dataset/cropped/satya_nadella\\satya_nadella30.png',
#   './dataset/cropped/satya_nadella\\satya_nadella32.png',
#   './dataset/cropped/satya_nadella\\satya_nadella33.png',
#   './dataset/cropped/satya_nadella\\satya_nadella4.png',
#   './dataset/cropped/satya_nadella\\satya_nadella5.png',
#   './dataset/cropped/satya_nadella\\satya_nadella6.png',
#   './dataset/cropped/satya_nadella\\satya_nadella7.png'],
#  'shantanu_narayen': ['./dataset/cropped/shantanu_narayen\\shantanu_narayen1.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen10.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen11.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen12.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen13.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen15.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen16.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen17.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen19.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen2.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen20.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen21.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen22.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen23.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen24.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen25.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen26.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen27.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen28.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen29.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen3.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen30.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen31.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen32.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen33.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen34.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen35.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen36.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen37.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen38.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen39.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen4.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen40.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen41.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen42.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen43.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen44.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen45.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen46.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen47.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen48.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen49.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen5.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen50.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen6.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen7.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen8.png',
#   './dataset/cropped/shantanu_narayen\\shantanu_narayen9.png'],
#  'sundar_pichai': ['./dataset/cropped/sundar_pichai\\sundar_pichai1.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai10.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai11.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai12.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai13.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai14.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai15.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai17.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai18.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai19.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai2.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai20.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai21.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai23.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai24.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai25.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai27.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai28.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai29.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai3.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai30.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai31.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai32.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai34.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai35.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai36.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai37.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai38.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai39.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai4.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai40.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai41.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai43.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai44.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai45.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai46.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai47.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai48.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai49.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai5.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai50.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai51.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai52.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai53.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai54.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai6.png',
#   './dataset/cropped/sundar_pichai\\sundar_pichai9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'azim-premji': 0,
#  'lakshmi_niwas_mittal': 1,
#  'mukesh_ambani': 2,
#  'nr_narayana_murthy': 3,
#  'ratan_tata': 4,
#  'ritesh_agarwal': 5,
#  'satya_nadella': 6,
#  'shantanu_narayen': 7,
#  'sundar_pichai': 8}

# %% [markdown]
# ### Images in cropped folder can be used for model training. We will use these raw images along with wavelet transformed images to train our classifier. Let's prepare X and y now

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[206],
#        [203],
#        [205],
#        ...,
#        [200],
#        [215],
#        [231]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (367, 4096)

# %% [markdown]
# ### Data cleaning process is done. Now we are ready to train our model

# %% [markdown]
# We will use SVM with rbf kernel tuned  with heuristic finetuning

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.75

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.75      0.86         8
#            1       0.82      0.69      0.75        13
#            2       0.86      0.50      0.63        12
#            3       1.00      0.20      0.33         5
#            4       0.64      0.78      0.70         9
#            5       0.71      0.94      0.81        16
#            6       1.00      0.57      0.73         7
#            7       0.67      1.00      0.80        14
#            8       0.70      0.88      0.78         8
#
#     accuracy                           0.75        92
#    macro avg       0.82      0.70      0.71        92
# weighted avg       0.79      0.75      0.74        92

# %% [markdown]
# ### Let's use GridSearch to try out different models with different paramets. Goal is to come up with best modle with best fine tuned parameters

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.792727
# 1        random_forest    0.505455
# 2  logistic_regression    0.832727
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.8260869565217391

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.5217391304347826

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.8260869565217391

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 8,  0,  0,  0,  0,  0,  0,  0,  0],
#        [ 0, 11,  0,  0,  0,  2,  0,  0,  0],
#        [ 0,  1,  9,  0,  1,  0,  0,  1,  0],
#        [ 1,  0,  0,  2,  0,  0,  0,  1,  1],
#        [ 0,  2,  0,  0,  6,  1,  0,  0,  0],
#        [ 0,  0,  1,  0,  0, 15,  0,  0,  0],
#        [ 0,  0,  0,  0,  0,  0,  6,  1,  0],
#        [ 0,  0,  0,  0,  0,  0,  0, 14,  0],
#        [ 0,  0,  1,  0,  0,  2,  0,  0,  5]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'azim-premji': 0,
#  'lakshmi_niwas_mittal': 1,
#  'mukesh_ambani': 2,
#  'nr_narayana_murthy': 3,
#  'ratan_tata': 4,
#  'ritesh_agarwal': 5,
#  'satya_nadella': 6,
#  'shantanu_narayen': 7,
#  'sundar_pichai': 8}

# %% [markdown]
# ### Save the trained model

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\heman\appdata\roaming\python\python310\site-packages (1.2.0)
# ['saved_model.pkl']

# %% [markdown]
# ### Save class dictionary

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
