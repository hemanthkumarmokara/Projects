# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("eamcet students(2020-22)list.xlsx")

# %%
df.head()
# Out:
#                            Name  Gender  Hallticket number           State  \
# 0                       Lokajit    Male       6.047202e+10  Andhra Pradesh
# 1                  Shaik Sajida    Male       6.047201e+10  Andhra Pradesh
# 2  GULLIPALLI SAI ROHITH NAIDU     Male       6.047202e+10   Andhrapradesh
# 3                      Kaditula  Female       6.047202e+10   Andhrapradesh
# 4                    Raktakamal    Male       6.047202e+10   Andhrapradesh
#
#         District         region  Intermediate_marks  Eamcet year  \
# 0        Krishna  Middle Andhra               989.0       2020.0
# 1  East Godavari  Middle Andhra               988.0       2020.0
# 2  East Godavari  Middle Andhra               954.0       2020.0
# 3  East Godavari  Middle Andhra               987.0       2020.0
# 4  Visakhapatnam   North Andhra               987.0       2020.0
#
#    eamcet marks     status Eamcet rank  \
# 0         124.0  Qualified         705
# 1         117.0  Qualified        1300
# ...

# %%
df=df.drop(['Name','Hallticket number','Coedu'],axis=1)

# %%
df.head()
# Out:
#    Gender           State       District         region  Intermediate_marks  \
# 0    Male  Andhra Pradesh        Krishna  Middle Andhra               989.0
# 1    Male  Andhra Pradesh  East Godavari  Middle Andhra               988.0
# 2    Male   Andhrapradesh  East Godavari  Middle Andhra               954.0
# 3  Female   Andhrapradesh  East Godavari  Middle Andhra               987.0
# 4    Male   Andhrapradesh  Visakhapatnam   North Andhra               987.0
#
#    Eamcet year  eamcet marks     status Eamcet rank  \
# 0       2020.0         124.0  Qualified         705
# 1       2020.0         117.0  Qualified        1300
# 2       2020.0         111.0  Qualified        1501
# 3       2020.0         110.0  Qualified        1570
# 4       2020.0         109.0  Qualified        1578
#
#                                Allotted college Branch
# 0               JNTUK COLLEGE OF ENGG. KAKINADA    CSE
# 1               JNTUK COLLEGE OF ENGG. KAKINADA    CSE
# ...

# %%
df['status'] = df['status'].replace({"Qualified": 1, "Not Qualified": 0})
df['Gender']=df['Gender'].replace({"Male":1,"Female":0})
df.head()
# Out:
#    Gender           State       District         region  Intermediate_marks  \
# 0     1.0  Andhra Pradesh        Krishna  Middle Andhra               989.0
# 1     1.0  Andhra Pradesh  East Godavari  Middle Andhra               988.0
# 2     1.0   Andhrapradesh  East Godavari  Middle Andhra               954.0
# 3     0.0   Andhrapradesh  East Godavari  Middle Andhra               987.0
# 4     1.0   Andhrapradesh  Visakhapatnam   North Andhra               987.0
#
#    Eamcet year  eamcet marks  status Eamcet rank  \
# 0       2020.0         124.0     1.0         705
# 1       2020.0         117.0     1.0        1300
# 2       2020.0         111.0     1.0        1501
# 3       2020.0         110.0     1.0        1570
# 4       2020.0         109.0     1.0        1578
#
#                                Allotted college Branch
# 0               JNTUK COLLEGE OF ENGG. KAKINADA    CSE
# 1               JNTUK COLLEGE OF ENGG. KAKINADA    CSE
# ...

# %%
df['status'] = pd.to_numeric(df['status'], errors='coerce')
df['Gender'] = pd.to_numeric(df['Gender'], errors='coerce')
df['Intermediate_marks'] = pd.to_numeric(df['Intermediate_marks'], errors='coerce')
df.head()
# Out:
#    Gender           State       District         region  Intermediate_marks  \
# 0     1.0  Andhra Pradesh        Krishna  Middle Andhra               989.0
# 1     1.0  Andhra Pradesh  East Godavari  Middle Andhra               988.0
# 2     1.0   Andhrapradesh  East Godavari  Middle Andhra               954.0
# 3     0.0   Andhrapradesh  East Godavari  Middle Andhra               987.0
# 4     1.0   Andhrapradesh  Visakhapatnam   North Andhra               987.0
#
#    Eamcet year  eamcet marks  status Eamcet rank  \
# 0       2020.0         124.0     1.0         705
# 1       2020.0         117.0     1.0        1300
# 2       2020.0         111.0     1.0        1501
# 3       2020.0         110.0     1.0        1570
# 4       2020.0         109.0     1.0        1578
#
#                                Allotted college Branch
# 0               JNTUK COLLEGE OF ENGG. KAKINADA    CSE
# 1               JNTUK COLLEGE OF ENGG. KAKINADA    CSE
# ...

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
ax1.hist(df[df['status'] == 1]['Intermediate_marks'], bins=10,edgecolor='black')  # Set the range using 'range'

# Set title and labels
ax1.set_title('Histogram of Intermediate Marks for Qualified Students')
ax1.set_xlabel('Intermediate Marks')
ax1.set_ylabel('Frequency')

ax2.hist(df[df['status'] == 0]['Intermediate_marks'], bins=10,edgecolor='black')  # Set the range using 'range'

# Set title and labels
ax2.set_title('Histogram of Intermediate Marks for Not Qualified Students')
ax2.set_xlabel('Intermediate Marks')
ax2.set_ylabel('Frequency')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
qualified_df = df[df['status'] == 1]
gender_counts = qualified_df['Gender'].value_counts()
ax1.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140)
ax1.set_title('Distribution of Qualified People by Gender')
not_qualified=df[df['status']==0]
gender_counts=not_qualified['Gender'].value_counts()
ax2.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140)
ax2.set_title('Distribution of not Qualified People by Gender')
labels = ['Male', 'Female']
plt.legend(title='Gender', labels=labels, loc='upper right')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
qualified_df = df[df['status'] == 1]
gender_counts = qualified_df['Eamcet year'].value_counts()
ax1.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140)
ax1.set_title('Distribution of Qualified People by Gender')
not_qualified_df = df[df['status'] == 0]
gender_counts = not_qualified_df['Eamcet year'].value_counts()
ax2.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140)
ax2.set_title('Distribution of Not Qualified People by Gender')
plt.show()

# %%
qualified_count = df['status'].sum()
not_qualified_count = len(df) - qualified_count
counts = [qualified_count, not_qualified_count]
labels = ['Qualified', 'Not Qualified']
colors = ['skyblue', 'lightcoral']
plt.figure(figsize=(6,6))
plt.pie(counts, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Qualified and Not Qualified People')
plt.axis('equal')  # Equal aspect ratio ensures that the pie chart is circular
plt.legend(title='status', labels=labels, loc='upper right')
# Display the pie chart
plt.show()

# %%
correlation_matrix = df.corr()
print(correlation_matrix)
# Out:
#                       Gender  Intermediate_marks  Eamcet year  eamcet marks  \
# Gender              1.000000            0.005703    -0.001982     -0.006352
# Intermediate_marks  0.005703            1.000000     0.025515      0.910156
# Eamcet year        -0.001982            0.025515     1.000000      0.016039
# eamcet marks       -0.006352            0.910156     0.016039      1.000000
# status             -0.033048            0.538329     0.009840      0.682522
#
#                       status
# Gender             -0.033048
# Intermediate_marks  0.538329
# Eamcet year         0.009840
# eamcet marks        0.682522
# status              1.000000
# C:\Users\heman\AppData\Local\Temp\ipykernel_556\2020863294.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0, linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
df.to_csv('preprocessed data.csv',index=False)
